# %% [markdown]
# <a href="https://colab.research.google.com/github/pranuk050-pixel/Python_learning-consepts/blob/main/10-08-2026%20Pandas_Class_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {
    "Month": ["Jan", "Feb", "Mar", "Apr", "May", "Jun"],
    "Sales": [45000, 52000, 48000, 61000, 70000, 76000],
    "Profit": [8000, 9500, 8500, 12000, 15000, 17000],
    "Customers": [120, 140, 135, 165, 190, 210],
    "Ad_Spend": [5000, 6000, 5500, 7000, 8500, 9000]
}

df = pd.DataFrame(data)

print(df)
# Out:
#   Month  Sales  Profit  Customers  Ad_Spend
# 0   Jan  45000    8000        120      5000
# 1   Feb  52000    9500        140      6000
# 2   Mar  48000    8500        135      5500
# 3   Apr  61000   12000        165      7000
# 4   May  70000   15000        190      8500
# 5   Jun  76000   17000        210      9000

# %%
df
# Out:
#   Month  Sales  Profit  Customers  Ad_Spend
# 0   Jan  45000    8000        120      5000
# 1   Feb  52000    9500        140      6000
# 2   Mar  48000    8500        135      5500
# 3   Apr  61000   12000        165      7000
# 4   May  70000   15000        190      8500
# 5   Jun  76000   17000        210      9000

# %%
df.plot(x='Month',y='Sales',kind='line',marker='o')
# Out:
# <Axes: xlabel='Month'>

# %%
df.plot(x='Month',y=['Sales','Profit'],kind='bar')
# Out:
# <Axes: xlabel='Month'>

# %%
df.plot(x='Sales',y='Profit',kind='scatter')
# Out:
# <Axes: xlabel='Sales', ylabel='Profit'>

# %%
df['Sales'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Sales'].plot(kind='box')
# Out:
# <Axes: >

# %%
df.set_index("Month",inplace=True)

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#   Month  Sales  Profit  Customers  Ad_Spend
# 0   Jan  45000    8000        120      5000
# 1   Feb  52000    9500        140      6000
# 2   Mar  48000    8500        135      5500
# 3   Apr  61000   12000        165      7000
# 4   May  70000   15000        190      8500
# 5   Jun  76000   17000        210      9000

# %%
df.set_index("Month",inplace=True)

# %%
df['Sales'].plot(kind='pie',autopct='%1.2f%%')
# Out:
# <Axes: ylabel='Sales'>

# %%
import pandas as pd
df=pd.read_excel("/content/Sample - Superstore Sales (Excel).xlsx")
df
# Out:
#       Row ID  Order ID Order Date Order Priority  Order Quantity       Sales  \
# 0          1         3 2010-10-13            Low               6    261.5400
# 1          2         6 2012-02-20  Not Specified               2      6.9300
# 2          3        32 2011-07-15           High              26   2808.0800
# 3          4        32 2011-07-15           High              24   1761.4000
# 4          5        32 2011-07-15           High              23    160.2335
# ...      ...       ...        ...            ...             ...         ...
# 8394    8395     59971 2011-05-31       Critical              26    437.7700
# 8395    8396     59971 2011-05-31       Critical              45    514.8600
# 8396    8397     59971 2011-05-31       Critical              12    356.2700
# 8397    8398     59973 2011-11-15            Low              29  11039.7500
# 8398    8399     59973 2011-11-15            Low              30   4982.9440
#
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Order Priority', 'Order Quantity',
#        'Sales', 'Discount', 'Ship Mode', 'Profit', 'Unit Price',
#        'Shipping Cost', 'Customer Name', 'City', 'Zip Code', 'State', 'Region',
#        'Customer Segment', 'Product Category', 'Product Sub-Category',
#        'Product Name', 'Product Container', 'Product Base Margin',
#        'Ship Date'],
#       dtype='object')

# %%
heatmap
                segment 1  segment 2
product name 1
name 2

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Order Priority', 'Order Quantity',
#        'Sales', 'Discount', 'Ship Mode', 'Profit', 'Unit Price',
#        'Shipping Cost', 'Customer Name', 'City', 'Zip Code', 'State', 'Region',
#        'Customer Segment', 'Product Category', 'Product Sub-Category',
#        'Product Name', 'Product Container', 'Product Base Margin',
#        'Ship Date'],
#       dtype='object')

# %%
df['Order Date'].head()
# Out:
# 0   2010-10-13
# 1   2012-02-20
# 2   2011-07-15
# 3   2011-07-15
# 4   2011-07-15
# Name: Order Date, dtype: datetime64[ns]

# %%
### Plotly, Streamlit

# %%
df['Region'].value_counts()
# Out:
# Region
# Central    2710
# West       1956
# East       1895
# South      1838
# Name: count, dtype: int64

# %%
df.groupby("Region")['Sales'].median().plot(kind='bar')
# Out:
# <Axes: xlabel='Region'>

# %%
df.groupby(["Region",'Product Category'])[['Sales','Profit']].describe()
# Out:
#                            Sales                                              \
#                            count         mean          std    min        25%
# Region  Product Category
# Central Furniture          586.0  2801.557860  3834.680380  11.01  337.03000
#         Office Supplies   1457.0   841.287982  2048.424660   2.24  100.87000
#         Technology         667.0  2746.173542  4124.820754  12.20  498.32000
# East    Furniture          414.0  3425.758401  4599.006884   8.48  398.22000
#         Office Supplies   1040.0   874.893606  2277.616234   3.42   89.93500
#         Technology         441.0  2467.830256  4329.056774  21.84  452.93000
# South   Furniture          335.0  2715.881242  3508.177936   7.15  444.39500
#         Office Supplies   1044.0   784.765757  1925.857440   4.97  100.01000
#         Technology         459.0  3096.086476  6418.630844  10.62  450.08825
# West    Furniture          389.0  3107.438154  4002.644569  11.08  342.97000
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Order Priority', 'Order Quantity',
#        'Sales', 'Discount', 'Ship Mode', 'Profit', 'Unit Price',
#        'Shipping Cost', 'Customer Name', 'City', 'Zip Code', 'State', 'Region',
#        'Customer Segment', 'Product Category', 'Product Sub-Category',
#        'Product Name', 'Product Container', 'Product Base Margin',
#        'Ship Date'],
#       dtype='object')
