# %% [markdown]
# <a href="https://colab.research.google.com/github/pranuk050-pixel/Python_learning-consepts/blob/main/10-08-2026Visualizations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#### matplotlib
#### seaborn
#### Plotly
#### Streamlit

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=sns.load_dataset("titanic") ### This a method of seaborn and it reads only the listed csvs
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
#### continous variables: age, fare
#### discrete variables : sex,class,survived,alone

# %%
df['age'].fillna(df['age'].median(),inplace=True)

# %%
df['age'].iloc[0:10]
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# 5    28.0
# 6    54.0
# 7     2.0
# 8    27.0
# 9    14.0
# Name: age, dtype: float64

# %%
plt.figure(figsize=(20,5))
plt.plot(df['age'].iloc[0:10],color='#F54927',marker='o')

# %%
plt.figure(figsize=(20,10))
plt.plot(df['age'].iloc[0:10],color='#F54927',marker='o',
         markersize=10,markerfacecolor='w',markeredgecolor='b',markeredgewidth=2)

# %%
plt.plot(df['age'].iloc[0:10])
plt.xlabel("index")
plt.ylabel("age")
plt.title("Index vs Age")
plt.xlim(0,5)
plt.ylim(10,30)
# Out:
# (10.0, 30.0)

# %%
plt.figure(figsize=(20,5))
plt.plot(df['age'].iloc[0:50])

# %%
### subplots

# %%
plt.figure(figsize=(30,5))
plt.subplot(1,4,1)
plt.plot(df['age'].iloc[0:10])
plt.subplot(1,4,2)
plt.plot(df['age'].iloc[10:20])
plt.subplot(1,4,3)
plt.plot(df['age'].iloc[20:30])
plt.subplot(1,4,4)
plt.plot(df['age'].iloc[30:40])

# %%
plt.figure(figsize=(20,20))
counter=1
for i in range(1,6):
  for j in range(1,6):
    plt.subplot(5,5,counter)
    counter=counter+1

# %%
plt.hist(df['fare'], bins=20)
# Out:
# (array([562., 170.,  67.,  39.,  15.,  16.,   2.,   0.,   9.,   2.,   6.,
#           0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   3.]),
#  array([  0.     ,  25.61646,  51.23292,  76.84938, 102.46584, 128.0823 ,
#         153.69876, 179.31522, 204.93168, 230.54814, 256.1646 , 281.78106,
#         307.39752, 333.01398, 358.63044, 384.2469 , 409.86336, 435.47982,
#         461.09628, 486.71274, 512.3292 ]),
#  <BarContainer object of 20 artists>)

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
x
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
x = df['survived'].value_counts()

plt.bar(x.index, x.values)
plt.title("Survival Count")
plt.xlabel("Survived")
plt.ylabel("Count")
plt.show()

# %%
x = df['pclass'].value_counts()

plt.bar(x.index, x.values)
plt.title("Passenger Class Count")
plt.xlabel("Pclass")
plt.ylabel("Count")
plt.show()

# %%
x = df['sex'].value_counts()
plt.bar(x.index, x.values)
# plt.title("Gender Count")
# plt.xlabel("Sex")
# plt.ylabel("Count")
# plt.show()
# Out:
# <BarContainer object of 2 artists>

# %%
plt.hist(df['age'].dropna(), bins=20)
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %%
df[(df['age']>20) & (df['age']<30)].shape[0]
# Out:
# 382

# %%
(df[(df['age']>0) & (df['age']<18)].shape[0]/df.shape[0])*100
# Out:
# 12.682379349046016

# %%
(df[(df['age']>60) & (df['age']<100)].shape[0]/df.shape[0])*100
# Out:
# 2.4691358024691357

# %%
plt.scatter(df['age'], df['fare'])
plt.title("Age vs Fare")
plt.xlabel("Age")
plt.ylabel("Fare")
plt.show()

# %%
df[df['fare']>150]['fare'].sum()/df['fare'].sum()
# Out:
# np.float64(0.24334370033894215)

# %%
df[df['fare']>150]['fare'].mean()
# Out:
# np.float64(240.7755793103448)

# %%
df[df['fare']<150]['fare'].mean()
# Out:
# np.float64(25.187305684454753)

# %%
df['fare'].mean()
# Out:
# np.float64(32.204207968574636)

# %%
df_subset=df.iloc[0:10]

# %%
df_subset[(df_subset['age']>30) &(df_subset['age']>30) ]['fare']
# Out:
# 1    71.2833
# 3    53.1000
# 4     8.0500
# 6    51.8625
# Name: fare, dtype: float64

# %%
(df_subset['age']>30)
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4     True
# 5    False
# 6     True
# 7    False
# 8    False
# 9    False
# Name: age, dtype: bool

# %%
sns.countplot(x='survived', data=df)
plt.show()

# %%
sns.boxplot(df['age'])
# Out:
# <Axes: ylabel='age'>

# %%
sns.histplot(x='fare', data=df, kde=True)
plt.show()

# %%
sns.scatterplot(x='age', y='fare',hue='survived',data=df)
plt.show()

# %%
#### bargraph
### scatter plot
### linegraph
### heatmap
### countplot
### linear model plot
### non linear model plot

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df['age'].iloc[0:200].values.reshape(20,10),annot=True,cmap='magma',linewidth=1,linecolor='r')
# Out:
# <Axes: >

# %%
df['pclass'].nunique()
# Out:
# 3

# %%
df['sex'].nunique()
# Out:
# 2

# %%
age
fare
pclass

pair grid  : 3*3

9

age vs fare
age vs pclass
age vs age

# %% [markdown]
# ### higher sales in age<30
