# %% [markdown]
# <a href="https://colab.research.google.com/github/pranuk050-pixel/Python_learning-consepts/blob/main/29-07-26-NumPy1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=[1,2,"Data"]
type(x)
# Out:
# list

# %%
x=(1,2,3)
type(x)
# Out:
# tuple

# %%
### Numeric Python

# %%
import numpy as np
y=np.array([1,2,3])
type(y)
# Out:
# numpy.ndarray

# %%
ndarray : n dimensional array

# %%
[1,2,3]

# %%
x=[1,2,3]
y=np.array([1,2,3])
print(type(x),type(y))
# Out:
# <class 'list'> <class 'numpy.ndarray'>

# %%
x=[1,2,3.6]
type(x[0]),type(x[1]),type(x[2])
# Out:
# (int, int, float)

# %%
x=[1,2,4]
x=np.array(x)
print(x)
type(x[0]),type(x[1]),type(x[2])
# Out:
# [1 2 4]
# (numpy.int64, numpy.int64, numpy.int64)

# %%
list : when we have multiple elements of different dataytpes it will not change the datatype of all elements
numpy : int==> float ===>complex ===>string

# %%
x=[1,2,3]
x/2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_464/597206274.py in <cell line: 0>()
#       1 x=[1,2,3]
# ----> 2 x/2
#
# TypeError: unsupported operand type(s) for /: 'list' and 'int'

# %%
x
# Out:
# [1, 2, 3]

# %%
y=np.array(x)
y/2
# Out:
# array([0.5, 1. , 1.5])

# %%
import numpy as np
data=np.random.randint(0,100,(5,5))

# %%
data
# Out:
# array([[57, 92, 36, 26, 37],
#        [10, 41, 85, 87, 91],
#        [36, 53, 76,  6, 66],
#        [15, 32, 46, 87, 21],
#        [71, 71, 42, 10, 49]])

# %%
data[-4:,-4:]
# Out:
# array([[41, 85, 87, 91],
#        [53, 76,  6, 66],
#        [32, 46, 87, 21],
#        [71, 42, 10, 49]])

# %%
data[0:2,-3:-1]
# Out:
# array([[36, 26],
#        [85, 87]])

# %%
data[-4:-2,0]
# Out:
# array([10, 36])

# %%
data[-3,-1]
# Out:
# np.int64(66)

# %%
data[0,0]
# Out:
# np.int64(57)

# %%
data=np.random.randint(0,255,(1080,1920,3))

# %%
data
# Out:
# array([[[205,  22,  52],
#         [118, 162, 178],
#         [ 34,  31,   5],
#         ...,
#         [ 92,  44, 217],
#         [ 87, 222, 124],
#         [195, 159, 102]],
#
#        [[197, 189, 249],
#         [ 24, 120,   2],
#         [ 83, 184, 236],
#         ...,
#         [ 62, 118, 142],
#         [ 14, 115, 235],
#         [247,  73, 120]],
#
#        [[103, 243, 106],
#         [ 40, 104, 145],
#         [ 10, 209, 199],
#         ...,
#         [ 84, 149,  66],
#         [204, 226,  90],
#         [ 18,  55, 122]],
#
#        ...,
#
#        [[178, 231, 101],
#         [ 94, 184,  41],
#         [145, 240, 214],
#         ...,
#         [149, 235, 170],
#         [179,  90,  41],
#         [ 20,  24, 199]],
#
#        [[ 75, 196,   0],
#         [203,  72,  57],
#         [ 87, 185,  88],
#         ...,
#         [ 96,  90,  63],
#         [ 11,  35, 226],
#         [ 34,  24, 196]],
#
#        [[ 44, 190, 212],
#         [114,  93,  76],
#         [233, 189, 240],
# ...

# %%
numpy array
if brightness
if zoom in
if green color increase
if blue color channle increase
if red color channel increase

# %%
import matplotlib.pyplot as plt
data=np.random.randint(0,1,(1080,1920,3))
data[0:100,0:100]=255
plt.imshow(data)

# %%
## Numpy 1d, 2d ,3d (images)
## inbuilt functions

# %%
data=np.random.randint(0,10,(3,3))

# %%
data
# Out:
# array([[2, 5, 3],
#        [0, 3, 6],
#        [2, 0, 2]])

# %%
np.random.rand(3,3)
# Out:
# array([[0.19369031, 0.93182381, 0.45829454],
#        [0.0421308 , 0.32495614, 0.68199683],
#        [0.75947259, 0.47718621, 0.92375023]])

# %%
np.random.randn(10).mean() ### randn : higher the values it becomes closer to zero mean value
# Out:
# np.float64(-0.013416482172585353)

# %%
np.random.randn(10) ### Normal distribution ### mean =0,std=1
# Out:
# array([-0.11284033, -0.07897559, -1.65244769, -1.67557843,  1.29305374,
#         0.97401125,  1.34059849,  0.93941283, -0.31191525, -1.07914238])

# %%
x=np.random.randint(0,100,(3,3))
x
# Out:
# array([[ 3, 74, 27],
#        [41, 39, 87],
#        [85, 70, 68]])

# %%
x.min(axis=1)
# Out:
# array([ 3, 39, 68])

# %%
x.min(axis=0)
# Out:
# array([ 3, 39, 27])

# %%
x=np.random.randint(0,100,(5,5))
x
# Out:
# array([[11, 22, 48, 17, 19],
#        [45, 89, 61,  5, 82],
#        [49, 81, 69, 55, 95],
#        [11, 77, 89, 48, 80],
#        [24, 29,  1, 18, 29]])

# %%
x.min(axis=1)
# Out:
# array([11,  5, 49, 11,  1])

# %%
x.max(axis=0)
# Out:
# array([49, 89, 89, 55, 95])

# %%
x=np.random.randint(0,100,(5,5))

# %%
x
# Out:
# array([[47, 98, 76, 13, 62],
#        [23,  3,  1,  3, 71],
#        [16, 54, 78, 81, 72],
#        [62, 97, 72, 57,  9],
#        [44, 78,  0, 16, 72]])

# %%
print(x.sum(axis=1))
print(x.sum(axis=0))
# Out:
# [296 101 301 297 210]
# [192 330 227 170 286]

# %%
# rows: stores
# columns: products
# values:sales
# each store wise highest sales
x.max(axis=1)
## product wise least sales
x.min(axis=0)
# Out:
# array([16,  3,  0,  3,  9])

# %%
x=np.random.randint(0,10,5)
x
# Out:
# array([4, 0, 1, 1, 1])

# %%
print(x.mean())
print(np.median(x))
print(x.std())
print(x.var())
# Out:
# 1.4
# 1.0
# 1.3564659966250538
# 1.8400000000000003

# %%
10.00 to 1.00
Sprint : Monday  (Functions, NumPy)

# %%
##
